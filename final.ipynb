# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('20192020air_10.csv')
df1=pd.read_csv('2019air.csv')
df2=pd.read_csv('2020air.csv')
df3=pd.read_csv('20192020air_25.csv')

# %% [markdown]
# 2019년 4월 16일~5월 20일 대기오염도 데이터

# %%
df1
# Out:
#           date  PM10  PM2.5  OZONE    NO2   CO    SO2
# 0   2019-04-16    49     20  0.032  0.027  0.4  0.005
# 1   2019-04-17    48     23  0.029  0.029  0.4  0.007
# 2   2019-04-18    39     23  0.031  0.017  0.3  0.004
# 3   2019-04-19    44     30  0.032  0.012  0.3  0.004
# 4   2019-04-20    46     23  0.044  0.010  0.3  0.004
# 5   2019-04-21    34     26  0.048  0.007  0.3  0.004
# 6   2019-04-22   101     39  0.039  0.021  0.4  0.004
# 7   2019-04-23    80     47  0.040  0.024  0.4  0.004
# 8   2019-04-24    39     30  0.035  0.017  0.3  0.003
# 9   2019-04-25    37     24  0.022  0.016  0.3  0.003
# 10  2019-04-26    21     11  0.022  0.015  0.3  0.003
# 11  2019-04-27    15      6  0.022  0.019  0.2  0.003
# 12  2019-04-28    20     14  0.028  0.016  0.2  0.004
# 13  2019-04-29    24     18  0.016  0.026  0.3  0.003
# 14  2019-04-30    29     21  0.025  0.022  0.3  0.004
# 15  2019-05-01    57     28  0.038  0.012  0.2  0.004
# ...

# %%
df1.to_csv('df1'+'.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# 2020년 4월 16일~5월 20일 대기오염도 데이터

# %%
df2
# Out:
#           date  PM10  PM2.5  OZONE    NO2   CO    SO2
# 0   2020-04-16    56     34  0.052  0.028  0.5  0.003
# 1   2020-04-17    40     24  0.051  0.013  0.4  0.002
# 2   2020-04-18    34     21  0.051  0.010  0.4  0.002
# 3   2020-04-19    23     23  0.038  0.013  0.4  0.002
# 4   2020-04-20    16     13  0.046  0.011  0.4  0.002
# 5   2020-04-21    36     12  0.045  0.008  0.3  0.002
# 6   2020-04-22    90     15  0.042  0.006  0.3  0.002
# 7   2020-04-23    42     14  0.038  0.010  0.3  0.002
# 8   2020-04-24    44     17  0.049  0.015  0.4  0.003
# 9   2020-04-25    60     27  0.070  0.011  0.5  0.003
# 10  2020-04-26    32     18  0.049  0.011  0.4  0.003
# 11  2020-04-27    35     21  0.044  0.020  0.4  0.003
# 12  2020-04-28    37     23  0.047  0.023  0.5  0.003
# 13  2020-04-29    44     28  0.062  0.020  0.5  0.004
# 14  2020-04-30    34     19  0.053  0.020  0.4  0.003
# 15  2020-05-01    44     28  0.063  0.007  0.4  0.003
# ...

# %%
df2.to_csv('df2'+'.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# 2020년 2019년 미세먼지

# %%
df
# Out:
#       date  PM10_2020  PM10_2019
# 0    04-16         56         49
# 1    04-17         40         48
# 2    04-18         34         39
# 3    04-19         23         44
# 4    04-20         16         46
# 5    04-21         36         34
# 6    04-22         90        101
# 7    04-23         42         80
# 8    04-24         44         39
# 9    04-25         60         37
# 10   04-26         32         21
# 11   04-27         35         15
# 12   04-28         37         20
# 13   04-29         44         24
# 14   04-30         34         29
# 15   05-01         44         57
# 16   05-02         47         69
# 17   05-03         24         56
# 18   05-04         41         77
# 19   05-05         38         67
# 20   05-06         43         48
# 21   05-07         26         54
# 22   05-08         27         51
# 23   05-09         13         44
# 24   05-10         31         49
# 25   05-11        109         54
# 26   05-12         51         60
# ...

# %%
df.to_csv('df'+'.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# 2020년 2019년 초미세먼지

# %%
df3
# Out:
#       date  PM2.5_2020  PM2.5_2019
# 0    04-16          34          20
# 1    04-17          24          23
# 2    04-18          21          23
# 3    04-19          23          30
# 4    04-20          13          23
# 5    04-21          12          26
# 6    04-22          15          39
# 7    04-23          14          47
# 8    04-24          17          30
# 9    04-25          27          24
# 10   04-26          18          11
# 11   04-27          21           6
# 12   04-28          23          14
# 13   04-29          28          18
# 14   04-30          19          21
# 15   05-01          28          28
# 16   05-02          29          20
# 17   05-03          19          29
# 18   05-04          23          61
# 19   05-05          26          46
# 20   05-06          24          12
# 21   05-07          10          18
# 22   05-08          15          22
# 23   05-09          11          25
# 24   05-10          31          33
# 25   05-11          38          33
# ...

# %%
df3.to_csv('df3'+'.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# 2020 대기오염 통계값

# %%
df2.describe()
# Out:
#              PM10      PM2.5      OZONE        NO2         CO        SO2
# count   35.000000  35.000000  35.000000  35.000000  35.000000  35.000000
# mean    39.485714  21.371429   0.046457   0.014486   0.448571   0.002657
# std     19.509231   8.768546   0.009835   0.005843   0.088688   0.000539
# min     10.000000   6.000000   0.020000   0.006000   0.300000   0.002000
# 25%     28.500000  15.000000   0.040500   0.010500   0.400000   0.002000
# 50%     37.000000  21.000000   0.047000   0.013000   0.400000   0.003000
# 75%     44.500000  26.500000   0.051000   0.018500   0.500000   0.003000
# max    109.000000  43.000000   0.070000   0.028000   0.700000   0.004000

# %%
df2.nlargest(5,columns='PM10')
# Out:
#           date  PM10  PM2.5  OZONE    NO2   CO    SO2
# 25  2020-05-11   109     38  0.058  0.012  0.6  0.003
# 6   2020-04-22    90     15  0.042  0.006  0.3  0.002
# 9   2020-04-25    60     27  0.070  0.011  0.5  0.003
# 0   2020-04-16    56     34  0.052  0.028  0.5  0.003
# 32  2020-05-18    56     43  0.048  0.015  0.7  0.003

# %%
df2.nsmallest(5,columns='PM10')
# Out:
#           date  PM10  PM2.5  OZONE    NO2   CO    SO2
# 34  2020-05-20    10      6  0.028  0.015  0.4  0.003
# 23  2020-05-09    13     11  0.044  0.009  0.4  0.002
# 33  2020-05-19    13      9  0.036  0.011  0.4  0.002
# 4   2020-04-20    16     13  0.046  0.011  0.4  0.002
# 3   2020-04-19    23     23  0.038  0.013  0.4  0.002

# %%
df2.plot('date')

# %% [markdown]
# 2020년 2019년 미세먼지 평균

# %%
print('2020 미세먼지 평균')
df2[['PM10','PM2.5']].mean()
# Out:
# 2020 미세먼지 평균
# PM10     39.485714
# PM2.5    21.371429
# dtype: float64

# %%
print('2019 대기오염도 평균')
df1[['PM10','PM2.5']].mean()
# Out:
# 2019 대기오염도 평균
# PM10     48.142857
# PM2.5    27.600000
# dtype: float64

# %%
df3.plot('date')
plt.title('PM10')
# Out:
# Text(0.5, 1.0, 'PM10')

# %%
df.plot('date')
plt.title('PM2.5')
# Out:
# Text(0.5, 1.0, 'PM2.5')

# %%
print('미세먼지와 초미세먼지 하락값')
print('PM10 : ',48.142857-39.485714)
print('PM2.5 : ',27.600000-21.371429)
# Out:
# 미세먼지와 초미세먼지 하락값
# PM10 :  8.657142999999998
# PM2.5 :  6.228571000000002
